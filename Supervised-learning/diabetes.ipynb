# %%
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error,r2_score,confusion_matrix
import numpy as np
import matplotlib.pyplot as plt

# %%
data = load_diabetes(as_frame=True)
data.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'DESCR', 'feature_names', 'data_filename', 'target_filename', 'data_module'])

# %%
X = data.data
X.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3        s4        s5        s6
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401 -0.002592  0.019907 -0.017646
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412 -0.039493 -0.068332 -0.092204
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356 -0.002592  0.002861 -0.025930
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038  0.034309  0.022688 -0.009362
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142 -0.002592 -0.031988 -0.046641

# %%
X.describe()
# Out:
#                 age           sex           bmi            bp  ...            s3            s4            s5            s6
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  ...  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -2.511817e-19  1.230790e-17 -2.245564e-16 -4.797570e-17  ... -5.777179e-18 -9.042540e-18  9.293722e-17  1.130318e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  ...  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.072256e-01 -4.464164e-02 -9.027530e-02 -1.123988e-01  ... -1.023071e-01 -7.639450e-02 -1.260971e-01 -1.377672e-01
# 25%   -3.729927e-02 -4.464164e-02 -3.422907e-02 -3.665608e-02  ... -3.511716e-02 -3.949338e-02 -3.324559e-02 -3.317903e-02
# 50%    5.383060e-03 -4.464164e-02 -7.283766e-03 -5.670422e-03  ... -6.584468e-03 -2.592262e-03 -1.947171e-03 -1.077698e-03
# 75%    3.807591e-02  5.068012e-02  3.124802e-02  3.564379e-02  ...  2.931150e-02  3.430886e-02  3.243232e-02  2.791705e-02
# max    1.107267e-01  5.068012e-02  1.705552e-01  1.320436e-01  ...  1.811791e-01  1.852344e-01  1.335973e-01  1.356118e-01
#
# [8 rows x 10 columns]

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     442 non-null    float64
#  1   sex     442 non-null    float64
#  2   bmi     442 non-null    float64
#  3   bp      442 non-null    float64
#  4   s1      442 non-null    float64
#  5   s2      442 non-null    float64
#  6   s3      442 non-null    float64
#  7   s4      442 non-null    float64
#  8   s5      442 non-null    float64
#  9   s6      442 non-null    float64
# dtypes: float64(10)
# memory usage: 34.7 KB

# %%
X.isna().sum()
# Out:
# age    0
# sex    0
# bmi    0
# bp     0
# s1     0
# s2     0
# s3     0
# s4     0
# s5     0
# s6     0
# dtype: int64

# %%
Y = data.target
Y.head()
# Out:
# 0    151.0
# 1     75.0
# 2    141.0
# 3    206.0
# 4    135.0
# Name: target, dtype: float64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
pipe = make_pipeline(StandardScaler(), DecisionTreeRegressor(random_state=1))

# %%
param = { 'decisiontreeregressor__max_depth':[2,4,5,7], 'decisiontreeregressor__min_samples_split':[2,3,4]}

# %%
model = GridSearchCV(pipe,param,cv=5)

# %%
model.fit(X_train, Y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('standardscaler', StandardScaler()),
#                                        ('decisiontreeregressor',
#                                         DecisionTreeRegressor(random_state=1))]),
#              param_grid={'decisiontreeregressor__max_depth': [2, 4, 5, 7],
#                          'decisiontreeregressor__min_samples_split': [2, 3, 4]})

# %%
model.best_params_
# Out:
# {'decisiontreeregressor__max_depth': 2,
#  'decisiontreeregressor__min_samples_split': 2}

# %%
y_pred = model.predict(X_test)

# %%
mse = mean_squared_error(Y_test, y_pred)
mse
# Out:
# 3735.4996177389003

# %%
rmse = np.sqrt(mse)
float(rmse)
# Out:
# 61.1187337707425

# %%
r2_score(Y_test, y_pred)
# Out:
# 0.2949428791304852
